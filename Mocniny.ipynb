# %% [markdown]
# # 📘 Mocniny
# ## 💡Motivace
#
# Mocniny se často objevují v reálném životě. Umožňují popisovat rychle rostoucí jevy, efektivně zapisovat opakované násobení a zjednodušovat výrazy.
#
# ### 1. Příklad z praxe - Růst počtu bakterií
# Bakterie se mohou dělit tak, že každých 20 minut se jejich počet zdvojnásobí.
# Pokud jich na začátku máme $1000$, potom po:
#
# - 20 minutách: $1000 \cdot 2 = 2000$
# - 40 minutách: $1000 \cdot 2^2 = 4000$
# - 60 minutách (1 hodina): $1000 \cdot 2^3 = 8000$
# - Po 1 dni: $N(72)=1000\cdot2^{72}$
#
# Pro obecný čas, například za 1 den (24 hodin = 1440 minut), vypočítáme počet dělení:
# $$ n = \frac{1440}{20} = 72 $$
# Celkový počet bakterií bude:
# $$ 1000 \cdot 2^{72} $$
#
# ### 2. Příklad z praxe - Finanční úročení
# Pokud na bankovním účtu uložíme $10\,000$ Kč s ročním úrokem 5% a úroky se připisují každý rok, pak po $n$ letech bude stav účtu:
# $$ 10\,000 \cdot 1.05^n $$

# %% [markdown]
# ## 🧩 Definice a vlastnosti
#
# Mocnina čísla $a$ s exponentem $n$ je opakované násobení čísla $a$:
# $$ a^n = \underbrace{a \cdot a \cdot \dots \cdot a}_{n\text{ krát}} $$
#
# **Základní vlastnosti:**
# 1. $a^0 = 1$ pro $a \neq 0$
# 2. $a^1 = a$
# 3. $a^m \cdot a^n = a^{m+n}$
# 4. $\frac{a^m}{a^n} = a^{m-n}$
# 5. $(a^m)^n = a^{m \cdot n}$
# 6. $(a \cdot b)^n = a^n \cdot b^n$
#
# ---
#
# ## Vzorce
#
# | Operace | Vzorec |
# |---------|--------|
# | Součin | $a^m \cdot a^n = a^{m+n}$ |
# | Podíl | $\frac{a^m}{a^n} = a^{m-n}$ |
# | Mocnina mocniny | $(a^m)^n = a^{m \cdot n}$ |
# | Mocnina součinu | $(a \cdot b)^n = a^n \cdot b^n$ |
# | Mocnina jedničky | $a^0 = 1$ |

# %% [markdown]
# ## 🔍Ukázka řešených příkladů
#
# ### 1. Jednoduché mocniny
# - $3^2 = 9$
# - $5^3 = 125$
# - $2^4 = 16$
#
# ### 2. Kombinace pravidel
# - $2^3 \cdot 2^4 = 2^{3+4} = 2^7 = 128$
# - $\frac{2^5}{2^2} = 2^{5-2} = 2^3 = 8$
# - $(3^2)^3 = 3^{2 \cdot 3} = 3^6 = 729$
# - $(2 \cdot 5)^3 = 2^3 \cdot 5^3 = 8 \cdot 125 = 1000$
#
# ### 3. Mocniny s negativními čísly
# - $(-2)^3 = -8$
# - $(-3)^2 = 9$
#
# ### 4. Mocniny z praxe
# - Růst bakterií: V čase nula máme 1000 bakterií, jaký bude jejich počet po 60 minutách, pokud počet se zdvojnásobí každých 20 minut:
#   $1000 \cdot 2^3 = 8000$
# - Finanční úročení: Kolik budu mít o 5 letech na účtu, když  vložím 10 000 Kč s 5 % ročním úrokem:
#   $10\,000 \cdot 1.05^5 \approx 12\,762.82$
#
# ### 5. Složitější kombinace
# - $(2^2 \cdot 3)^3 = (4 \cdot 3)^3 = 12^3 = 1728$
# - $\frac{(3^3 \cdot 2^2)}{3^2} = 3^{3-2} \cdot 2^2 = 3 \cdot 4 = 12$

# %% [markdown]
# ## Příklady k procvičení
#
# - Spočítejte $5^3$
# - Spočítejte $2^4 \cdot 2^3$
# - Spočítejte $\frac{3^5}{3^2}$
# - Spočítejte $(4^2)^3$
# - Spočítejte $(3 \cdot 2)^4$
# - Počáteční investice 2000 Kč s 3% ročním úrokem, po 5 letech?

# %% [markdown]
# ## ✏️Příklady k procvičení
#
# ### 1. Jednoduché mocniny
# 1. Spočítejte $4^2$
# 2. Spočítejte $6^3$
# 3. Spočítejte $2^5$
#
# ### 2. Kombinace pravidel
# 4. Spočítejte $(3^2) \cdot (3^4)$
# 5. Spočítejte $\frac{2^6}{2^3}$
# 6. Spočítejte $(5^2)^3$
# 7. Spočítejte $(2 \cdot 4)^3$
#
# ### 3. Mocniny s negativními čísly
# 8. Spočítejte $(-3)^3$
# 9. Spočítejte $(-4)^2$
#
# ### 4. Mocniny z praxe
# 10. Počáteční počet bakterií je 500, každých 30 minut se počet zdvojnásobí. Kolik bakterií bude po 2 hodinách?
# 11. Na účtu je 8 000 Kč s ročním úrokem 4 %. Kolik bude na účtu po 3 letech?
# 12. Představme si, že nová stránka na sociální síti získává každý den dvakrát tolik sledujících než předchozí den. Počáteční počet sledujících: $S_0 = 100$. Chceme spočítat počet sledujících po 10 dnech.
#
# ### 5. Složitější kombinace
# 13. Spočítejte $(2^3 \cdot 3^2)^2$
# 14. Spočítejte $\frac{(4^3 \cdot 2^4)}{2^2}$
# 15. Spočítejte $(5 \cdot 3^2)^3$

# %% [markdown]
# ## ✨ Shrnutí
# - Mocniny jsou opakované násobení.
# - Umožňují rychlý zápis a výpočty.
# - Základní vlastnosti usnadňují práci s exponenty.
# - Mocniny mají uplatnění v přírodních i ekonomických procesech.
#
# - Exponent 0 dává vždy 1.
# - Záporný exponent znamená převrácenou hodnotu.
# - Při počítání s mocninami stejného základu sčítáme nebo odčítáme exponenty.
# - Mocnina mocniny = násobíme exponenty.
