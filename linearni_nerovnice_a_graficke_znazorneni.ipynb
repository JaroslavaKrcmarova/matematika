# %% [markdown]
# # 📘 Lineární nerovnice a jejich grafické znázornění

# %% [markdown]
# ## 🔹 Co je lineární nerovnice
# Lineární nerovnice je nerovnice, která obsahuje neznámou v prvním stupni, např.
# \( ax + b < 0 \), \( ax + b > 0 \), \( ax + b \leq 0 \), \( ax + b \geq 0 \).
#
# Řešením lineární nerovnice je množina všech hodnot proměnné \(x\), pro které nerovnice platí.
#
# ---
#
# ## 🔹 Grafické znázornění nerovnic
# Grafem lineární nerovnice v rovině je **polorovina** ohraničená přímkou.
# - Přímka: \( ax + by = c \)
# - Pokud je znaménko **<** nebo **>**, přímka se kreslí **čárkovaně**.
# - Pokud je znaménko **≤** nebo **≥**, přímka se kreslí **plnou** čarou.
# - Jedna z polorovin představuje řešení – obvykle se vyznačuje vyšrafováním nebo jiným zabarvením.
#
# ---
#
# ## 🔹 Co je polorovina
# Polorovina je část roviny rozdělená přímkou.
# - Přímka \( p \) rozděluje rovinu na **dvě poloroviny**.
# - Každý bod roviny leží buď v první, druhé polorovině, nebo přímo na přímce.
#
# ---
#
# ## 🔹 Příklad 1: Graf nerovnice \( y > 2x - 1 \)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 400)
y = 2*x - 1

plt.figure(figsize=(6,6))
plt.plot(x, y, '--', label='y = 2x - 1 (hranice)')
plt.fill_between(x, y, y2=10, color='lightblue', alpha=0.3, label='y > 2x - 1')

plt.title('Grafické řešení nerovnice y > 2x - 1')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.axis('equal')
plt.show()

# %% [markdown]
# ---
#
# ## 🔹 Soustava lineárních nerovnic
# Soustava lineárních nerovnic znamená, že hledáme průnik (společné řešení) více nerovnic.
#
# Například:
# \[
# \begin{cases}
# y \geq x + 1 \\
# y \leq -x + 3
# \end{cases}
# \]
#
# Řešením je oblast, kde se obě poloroviny překrývají.

# %%
x = np.linspace(-5, 5, 400)
y1 = x + 1
y2 = -x + 3

plt.figure(figsize=(6,6))
plt.plot(x, y1, '-', label='y = x + 1')
plt.plot(x, y2, '-', label='y = -x + 3')
plt.fill_between(x, y1, y2, where=(y2>y1), color='lightgreen', alpha=0.3, label='Řešení soustavy')

plt.title('Soustava lineárních nerovnic')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.axis('equal')
plt.show()

# %% [markdown]
# ---
#
# ## 🔹 Shrnutí
# - Lineární nerovnice má tvar \( ax + b < 0 \) apod.
# - Grafem je **polorovina** ohraničená přímkou.
# - Znaménko určuje, kterou část roviny zvolíme.
# - U soustavy hledáme průnik všech řešení.
#
# ---
#
# ## ✏️ Úkoly k procvičení
# 1. Narýsuj graf nerovnice \( y < -x + 2 \).
# 2. Urči polorovinu odpovídající \( y \geq 2x + 1 \).
# 3. Vyřeš soustavu nerovnic graficky:
#    \[
#    \begin{cases}
#    y \leq x + 3 \\
#    y \geq -2x
#    \end{cases}
#    \]
