# %% [markdown]
# # 🧮 Řešení kvadratické rovnice
#
# ## 💡 Motivace
#
# Kvadratické rovnice se objevují v mnoha praktických situacích.
# Například hledáme okamžik, kdy míček dosáhne země při hodu do výšky — jeho výška v čase odpovídá **kvadratické funkci**.
# Podobně při výpočtu optimálního zisku, trajektorie projektilu nebo maximálního dosahu.
#
# Proto je umět řešit kvadratickou rovnici velmi užitečné!
#
# ---
#
# ## 📘 Co je kvadratická rovnice?
#
# Kvadratická rovnice má tvar:
#
# $$ ax^2 + bx + c = 0, \quad a \ne 0 $$
#
# kde:
#
# * ( a ) je koeficient u ( x^2 ),
# * ( b ) je koeficient u ( x ),
# * ( c ) je absolutní člen.
#
# ---
#
# ## 🔍 Diskriminant
#
# Pro nalezení kořenů používáme **diskriminant**:
#
# $$ D = b^2 - 4ac $$
#
# Diskriminant rozhoduje o počtu řešení:
#
# * **(D > 0)** – dva různé reálné kořeny
# * **(D = 0)** – jeden dvojnásobný kořen
# * **(D < 0)** – žádné reálné řešení
#
# ---
#
# ## 🧩 Vzorce pro výpočet kořenů
#
# Pro kořeny platí:
#
# $$
# x_1 = \frac{-b + \sqrt{D}}{2a}, \qquad
# x_2 = \frac{-b - \sqrt{D}}{2a}
# $$
#
# Pokud (D = 0), obě řešení splývají:
#
# $$ x = \frac{-b}{2a} $$
#
# ---
#
# # ✏️ Ukázkový příklad
#
# **Vyřeš kvadratickou rovnici:**
#
# $$ 2x^2 - 5x - 3 = 0 $$
#
# ### 1️⃣ Určíme koeficienty
#
# * ( a = 2 )
# * ( b = -5 )
# * ( c = -3 )
#
# ### 2️⃣ Vypočítáme diskriminant
#
# $$
# D = b^2 - 4ac = (-5)^2 - 4\cdot2\cdot(-3)
# $$
#
# $$
# D = 25 + 24 = 49
# $$
#
# ### 3️⃣ Diskriminant je kladný
#
# → rovnice má **dva reálné kořeny**
#
# ### 4️⃣ Vypočítáme kořeny
#
# $$
# x_1 = \frac{5 + \sqrt{49}}{4} = \frac{5+7}{4} = 3
# $$
#
# $$
# x_2 = \frac{5 - \sqrt{49}}{4} = \frac{5-7}{4} = -\frac{1}{2}
# $$
#
# ### ✔️ Výsledek:
#
# $$ x_1 = 3,\qquad x_2 = -\frac12 $$
#
# ---
#
# # 📚 Příklady k procvičení
#
# 1. ( x^2 - 4x - 5 = 0 )
# 2. ( 3x^2 + 6x + 3 = 0 )
# 3. ( 2x^2 - 3x + 7 = 0 )
# 4. ( -x^2 + 5x = 0 )
# 5. ( 4x^2 + 4x + 1 = 0 )
#
# ---
#
# # ✨ Shrnutí
#
# * Kvadratická rovnice má tvar ( ax^2 + bx + c = 0 ).
# * Dopředu vždy zkontrolujeme, že ( a \ne 0 ).
# * Počet řešení určuje diskriminant
#   $$ D = b^2 - 4ac $$
# * Kořeny se počítají podle známého vzorce
