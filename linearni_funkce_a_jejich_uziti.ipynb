# %% [markdown]
# # Linearni funkce a jejich uziti
#
# ## 📘 Úvod
# Funkce je předpis, který každému prvku z množiny D (definiční obor) přiřazuje právě jeden prvek z množiny H (obor hodnot).
# Zapisujeme: y = f(x)
# Například: y = 2x + 1
#
# ---
# ### 🧮 1. Lineární funkce – definice, vlastnosti
#
# Definice:
# Lineární funkce je každá funkce tvaru:
# f(x) = ax + b
# kde a, b ∈ R
#
# - a – směrnice přímky (určuje, jak je přímka stoupající nebo klesající)
# - b – posunutí po ose y (průsečík s osou y)
#
# Vlastnosti:
# - D(f) = R
# - H(f) = R
# - Funkce není omezená
# - Monotónnost:
#   - a > 0 → rostoucí
#   - a < 0 → klesající
#   - a = 0 → konstantní
# - Sudost / lichost: obecně není ani sudá ani lichá
#
# ---
# ### 📉 2. Graf lineární funkce
#
# Grafem lineární funkce je přímka.
#
# Průsečíky s osami:
# - osa y: x = 0 → y = b → Py = (0, b)
# - osa x: y = 0 → 0 = ax + b → x = -b/a → Px = (-b/a, 0)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 100)
y = 2*x + 1

plt.figure(figsize=(6,4))
plt.axhline(0, color='black', linewidth=0.8)
plt.axvline(0, color='black', linewidth=0.8)
plt.plot(x, y, label='f(x) = 2x + 1')
plt.scatter(0, 1, color='red', label='Py (0,1)')
plt.scatter(-0.5, 0, color='green', label='Px (-0.5,0)')
plt.title('Graf lineární funkce f(x) = 2x + 1')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# ### ✏️ 3. Určení předpisu z grafu
#
# Pokud známe dva body přímky A(x₁, y₁) a B(x₂, y₂):
#
# Směrnice: a = (y₂ - y₁) / (x₂ - x₁)
# Dosazením jednoho bodu do f(x) = ax + b určíme b.

# %%
x1, y1 = 1, 3
x2, y2 = 4, 9
a = (y2 - y1) / (x2 - x1)
b = y1 - a*x1
print(f'Předpis funkce pro body A(1,3) a B(4,9): f(x) = {a}x + {b}')

# %% [markdown]
# ---
# ### ⚖️ 4. Grafické řešení rovnic a nerovnic
#
# Rovnice f(x) = g(x) → průsečíky grafů
# Nerovnice f(x) > g(x) → oblast, kde je jeden graf nad druhým

# %%
x = np.linspace(-3, 5, 200)
f = 2*x - 1
g = -x + 4

plt.figure(figsize=(6,4))
plt.plot(x, f, label='f(x) = 2x - 1')
plt.plot(x, g, label='g(x) = -x + 4')
plt.axhline(0, color='black', linewidth=0.8)
plt.axvline(0, color='black', linewidth=0.8)
plt.grid(True)
plt.legend()
plt.title('Grafické řešení rovnice f(x) = g(x)')
plt.show()

print('Průsečík má souřadnice: (5/3, 7/3)')

# %% [markdown]
# ---
# ### 💡 5. Příklady k procvičení
#
# 1️⃣ Narýsuj funkce:
# - y = -x + 2
# - y = 0.5x - 1
# - y = 3x
#
# 2️⃣ Urči předpis funkce pro body A(0,2) a B(2,6)
# 3️⃣ Graficky vyřeš soustavu:
#   - y = 2x + 1
#   - y = -x + 4
# 4️⃣ Urči, kde je funkce f(x) = 2x + 1 větší než g(x) = -x + 4
